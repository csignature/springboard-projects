# %% [markdown]
# # Which features are most important for given Airbnb prices?

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import sklearn
import seaborn as sns
import matplotlib as mpl

# %%
airbnb17 = pd.read_csv('airbnb17.csv',index_col=0)
airbnb17.head()
# Out:
#         accommodates  availability_30  availability_365  availability_60  \
# 678010           2.0              0.0               1.0              0.0
# 678012           3.0             12.0             288.0             29.0
# 678013           2.0              0.0               0.0              0.0
# 678015           3.0              4.0             154.0             34.0
# 678016           2.0              0.0               0.0              0.0
#
#         availability_90  bathrooms  bedrooms  beds  \
# 678010              0.0        1.0       1.0   2.0
# 678012             47.0        1.0       1.0   1.0
# 678013              0.0        1.0       1.0   1.0
# 678015             64.0        1.0       1.0   1.0
# 678016              0.0        1.0       1.0   1.0
#
#         calculated_host_listings_count        date   ...     \
# 678010                             1.0  2017-01-01   ...
# 678012                             1.0  2017-01-01   ...
# ...

# %%
from sklearn.linear_model import LinearRegression
X = airbnb17[['availability_30','availability_60','availability_90','availability_365','zipcode','accommodates','bathrooms','bedrooms','beds','guests_included','minimum_nights','maximum_nights','number_of_reviews','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','calculated_host_listings_count']]

lm = LinearRegression()
lm.fit(X,airbnb17.price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Estimated intercept coefficient:' + str(lm.intercept_))
print('Number of coefficients:' + str(len(lm.coef_)))
# Out:
# Estimated intercept coefficient:357.062194259
# Number of coefficients:21

# %%
coef_df = pd.DataFrame(list(zip(X.columns, lm.coef_)), columns = ['features','coef'])
coef_df
# Out:
#                           features          coef
# 0                  availability_30  8.638830e-01
# 1                  availability_60  1.041914e-01
# 2                  availability_90 -1.102109e-01
# 3                 availability_365  2.121158e-02
# 4                          zipcode -4.960626e-02
# 5                     accommodates  3.111871e+01
# 6                        bathrooms  6.519665e+01
# 7                         bedrooms  2.211020e+01
# 8                             beds -1.019585e+01
# 9                  guests_included  2.901103e+00
# 10                  minimum_nights  6.534102e-01
# 11                  maximum_nights  3.367420e-08
# 12               number_of_reviews -1.708643e-01
# 13            review_scores_rating  1.421609e+00
# 14          review_scores_accuracy  2.193542e+00
# 15       review_scores_cleanliness  2.183927e+00
# 16           review_scores_checkin -8.386045e+00
# 17     review_scores_communication -2.665313e+00
# ...
